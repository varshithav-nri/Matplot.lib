# %% [markdown]
# <a href="https://colab.research.google.com/github/varshithav-nri/Matplot.lib/blob/main/Dataframe_6_2_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1 = []
a2 = []
a3 = []

# %%
for _ in range(1000):
  a1.append(random.randint(0,100))
  a2.append(random.randint(50,70))
  a3.append(random.randint(5,10))

# %%
a1
# Out:
# [43,
#  33,
#  91,
#  33,
#  1,
#  48,
#  11,
#  83,
#  78,
#  78,
#  55,
#  38,
#  17,
#  98,
#  14,
#  89,
#  0,
#  55,
#  44,
#  17,
#  72,
#  59,
#  92,
#  96,
#  94,
#  30,
#  53,
#  97,
#  31,
#  40,
#  96,
#  54,
#  60,
#  22,
#  10,
#  99,
#  53,
#  74,
#  12,
#  40,
#  18,
#  45,
#  9,
#  13,
#  33,
#  39,
#  61,
#  2,
#  56,
#  1,
#  23,
#  37,
#  69,
#  99,
#  83,
#  49,
#  57,
#  75,
#  31,
#  54,
#  84,
#  61,
#  66,
#  66,
#  2,
#  21,
#  65,
#  27,
#  86,
#  31,
#  97,
#  66,
#  93,
#  68,
#  80,
#  21,
#  78,
#  31,
#  63,
#  73,
#  92,
#  46,
#  79,
#  8,
#  76,
#  17,
#  34,
#  73,
#  28,
#  33,
#  33,
#  83,
#  21,
#  16,
#  95,
#  5,
#  40,
#  40,
#  86,
#  89,
#  16,
#  34,
#  84,
#  22,
#  32,
#  94,
#  61,
#  46,
#  76,
#  92,
#  82,
#  78,
#  75,
#  50,
#  44,
#  24,
#  52,
#  9,
#  100,
#  87,
#  69,
#  34,
#  44,
#  59,
#  92,
#  90,
#  58,
#  31,
#  12,
#  89,
#  31,
#  24,
#  42,
#  74,
#  42,
#  13,
#  13,
#  8,
#  49,
#  54,
#  52,
#  20,
#  50,
#  12,
# ...

# %%
df = {
     'grade' : a1,
     'weight' : a2,
     'friends' : a3,
     }

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends
# 0       43      66        6
# 1       33      51        6
# 2       91      66       10
# 3       33      60       10
# 4        1      53        6
# ..     ...     ...      ...
# 995     36      50        9
# 996     62      59        7
# 997     30      67        9
# 998     33      56        7
# 999     91      68       10
#
# [1000 rows x 3 columns]

# %%
df1.describe()
# Out:
#              grade       weight      friends
# count  1000.000000  1000.000000  1000.000000
# mean     50.487000    60.158000     7.460000
# std      29.377523     6.048274     1.720279
# min       0.000000    50.000000     5.000000
# 25%      25.000000    55.000000     6.000000
# 50%      49.500000    60.000000     7.000000
# 75%      77.000000    65.000000     9.000000
# max     100.000000    70.000000    10.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
friend5 = df1['friends'] > 7

# %%
df1[friend5].describe()
# Out:
#             grade      weight     friends
# count  495.000000  495.000000  495.000000
# mean    50.494949   59.953535    8.979798
# std     28.610951    5.858993    0.829367
# min      0.000000   50.000000    8.000000
# 25%     25.500000   55.000000    8.000000
# 50%     50.000000   60.000000    9.000000
# 75%     75.000000   65.000000   10.000000
# max    100.000000   70.000000   10.000000

# %%
df1[friend5]
# Out:
#      grade  weight  friends
# 2       91      66       10
# 3       33      60       10
# 5       48      64        8
# 8       78      53       10
# 10      55      69        8
# ..     ...     ...      ...
# 993     19      57        9
# 994     33      68        8
# 995     36      50        9
# 997     30      67        9
# 999     91      68       10
#
# [495 rows x 3 columns]

# %%
grade50 = df1['grade'] > 50

# %%
df1[grade50]
# Out:
#      grade  weight  friends
# 2       91      66       10
# 7       83      65        6
# 8       78      53       10
# 9       78      66        6
# 10      55      69        8
# ..     ...     ...      ...
# 984     98      66        5
# 986     98      60        9
# 989     97      59        9
# 996     62      59        7
# 999     91      68       10
#
# [486 rows x 3 columns]

# %%
df1[friend5 & grade50]
# Out:
#      grade  weight  friends
# 2       91      66       10
# 8       78      53       10
# 10      55      69        8
# 20      72      53        8
# 24      94      63        8
# ..     ...     ...      ...
# 980     88      61        8
# 983     73      62        8
# 986     98      60        9
# 989     97      59        9
# 999     91      68       10
#
# [243 rows x 3 columns]

# %%
df1[friend5 & grade50]['grade']
# Out:
# 2      91
# 8      78
# 10     55
# 20     72
# 24     94
#        ..
# 980    88
# 983    73
# 986    98
# 989    97
# 999    91
# Name: grade, Length: 243, dtype: int64

# %%
df1[friend5 & grade50].value_counts()
# Out:
# grade  weight  friends
# 87     64      10         2
# 97     59      9          2
# 52     60      10         2
#        61      8          2
# 91     68      10         2
#                          ..
# 69     53      8          1
#        59      8          1
#        67      9          1
#        68      8          1
# 100    69      9          1
# Name: count, Length: 237, dtype: int64

# %%
friend9 = df1['friends'] > 9
grade98 = df1['grade'] > 98

# %%
df1[friend9 & grade98]
# Out:
#      grade  weight  friends
# 476     99      60       10
# 782    100      65       10

# %%
df1[friend9 & grade98].value_counts()
# Out:
# grade  weight  friends
# 99     60      10         1
# 100    65      10         1
# Name: count, dtype: int64

# %%
df1[friend5 & grade98].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1[friend5 & grade50].plot()
# Out:
# <Axes: >

# %%
df1[friend5 & grade50].plot(x= 'grade', y= 'friends')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend5 & grade50].plot(x= 'grade', y= 'friends', kind= 'pie')
# Out:
# <Axes: ylabel='friends'>

# %%
df1[friend5 & grade50].plot(x= 'grade', y= 'friends', kind= 'barh')
# Out:
# <Axes: ylabel='grade'>

# %%
df1[friend5 & grade98].plot(x= 'grade', y= 'friends', kind= 'pie')
# Out:
# <Axes: ylabel='friends'>

# %%
df1[friend5 & grade98].plot(x= 'grade', y= 'friends', kind= 'barh')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend('Test Data')
plt.show()

# %%
from matplotlib import pyplot as plt

# %%
fdf = df1[friend5 & grade50]
